# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime

# %%
covid_df=pd.read_csv("covid_19_india.csv")

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15114 entries, 0 to 15113
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       15086 non-null  float64
#  1   Date                      15086 non-null  object
#  2   Time                      15086 non-null  object
#  3   State/UnionTerritory      15086 non-null  object
#  4   ConfirmedIndianNational   15086 non-null  object
#  5   ConfirmedForeignNational  15086 non-null  object
#  6   Cured                     15086 non-null  float64
#  7   Deaths                    15086 non-null  float64
#  8   Confirmed                 15086 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 1.0+ MB

# %%
covid_df.notnull()
# Out:
#          Sno   Date   Time  State/UnionTerritory  ConfirmedIndianNational  \
# 0       True   True   True                  True                     True
# 1       True   True   True                  True                     True
# 2       True   True   True                  True                     True
# 3       True   True   True                  True                     True
# 4       True   True   True                  True                     True
# ...      ...    ...    ...                   ...                      ...
# 15109  False  False  False                 False                    False
# 15110  False  False  False                 False                    False
# 15111  False  False  False                 False                    False
# 15112  False  False  False                 False                    False
# 15113  False  False  False                 False                    False
#
#        ConfirmedForeignNational  Cured  Deaths  Confirmed
# 0                          True   True    True       True
# 1                          True   True    True       True
# 2                          True   True    True       True
# 3                          True   True    True       True
# 4                          True   True    True       True
# ...                         ...    ...     ...        ...
# 15109                     False  False   False      False
# 15110                     False  False   False      False
# 15111                     False  False   False      False
# 15112                     False  False   False      False
# 15113                     False  False   False      False
#
# [15114 rows x 9 columns]

# %%
covid_df=covid_df.dropna()

# %%
covid_df.tail()
# Out:
#            Sno        Date     Time State/UnionTerritory  \
# 15081  15082.0  2021-05-19  8:00 AM            Telangana
# 15082  15083.0  2021-05-19  8:00 AM              Tripura
# 15083  15084.0  2021-05-19  8:00 AM          Uttarakhand
# 15084  15085.0  2021-05-19  8:00 AM        Uttar Pradesh
# 15085  15086.0  2021-05-19  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational      Cured   Deaths  \
# 15081                       -                        -   485644.0   3012.0
# 15082                       -                        -    36402.0    450.0
# 15083                       -                        -   214426.0   5132.0
# 15084                       -                        -  1483249.0  18072.0
# 15085                       -                        -  1026492.0  13576.0
#
#        Confirmed
# 15081   536766.0
# 15082    42776.0
# 15083   295790.0
# 15084  1637663.0
# 15085  1171861.0

# %%
covid_df.head()
# Out:
#          Date State/UnionTerritory  Cured  Deaths  Confirmed
# 0  2020-01-30               Kerala    0.0     0.0        1.0
# 1  2020-01-31               Kerala    0.0     0.0        1.0
# 2  2020-02-01               Kerala    0.0     0.0        2.0
# 3  2020-02-02               Kerala    0.0     0.0        3.0
# 4  2020-02-03               Kerala    0.0     0.0        3.0

# %%
vaccine_df=pd.read_csv("covid_vaccine_statewise.csv")

# %%
vaccine_df.head()
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
#
#    Transgender (Doses Administered)  ...  18-44 Years (Doses Administered)  \
# 0                               NaN  ...                               NaN
# 1                               NaN  ...                               NaN
# 2                               NaN  ...                               NaN
# 3                               NaN  ...                               NaN
# 4                               NaN  ...                               NaN
#
#    45-60 Years (Doses Administered)  60+ Years (Doses Administered)  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
#
#    18-44 Years(Individuals Vaccinated)  45-60 Years(Individuals Vaccinated)  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#    60+ Years(Individuals Vaccinated)  Male(Individuals Vaccinated)  \
# 0                                NaN                       23757.0
# 1                                NaN                       27348.0
# 2                                NaN                       41361.0
# 3                                NaN                       81901.0
# 4                                NaN                       98111.0
#
#    Female(Individuals Vaccinated)  Transgender(Individuals Vaccinated)  \
# 0                         24517.0                                  2.0
# 1                         31252.0                                  4.0
# 2                         58083.0                                  5.0
# 3                        113613.0                                 11.0
# 4                        153145.0                                 24.0
#
#    Total Individuals Vaccinated
# 0                       48276.0
# 1                       58604.0
# 2                       99449.0
# 3                      195525.0
# 4                      251280.0
#
# [5 rows x 24 columns]

# %%
covid_df['Date']=pd.to_datetime(covid_df['Date'],format='%Y-%m-%d')

# %%
covid_df.head()
# Out:
#         Date State/UnionTerritory  Cured  Deaths  Confirmed
# 0 2020-01-30               Kerala    0.0     0.0        1.0
# 1 2020-01-31               Kerala    0.0     0.0        1.0
# 2 2020-02-01               Kerala    0.0     0.0        2.0
# 3 2020-02-02               Kerala    0.0     0.0        3.0
# 4 2020-02-03               Kerala    0.0     0.0        3.0

# %%
covid_df['Active_cases']=covid_df['Confirmed']-(covid_df['Cured']+covid_df['Deaths'])

# %%
covid_df.tail()
# Out:
#             Date State/UnionTerritory      Cured   Deaths  Confirmed  \
# 15081 2021-05-19            Telangana   485644.0   3012.0   536766.0
# 15082 2021-05-19              Tripura    36402.0    450.0    42776.0
# 15083 2021-05-19          Uttarakhand   214426.0   5132.0   295790.0
# 15084 2021-05-19        Uttar Pradesh  1483249.0  18072.0  1637663.0
# 15085 2021-05-19          West Bengal  1026492.0  13576.0  1171861.0
#
#        Active_cases
# 15081       48110.0
# 15082        5924.0
# 15083       76232.0
# 15084      136342.0
# 15085      131793.0

# %%
statewise=pd.pivot_table(covid_df,values=['Confirmed','Deaths','Cured'],index="State/UnionTerritory",aggfunc=max)

# %%
statewise["Recovery Rate"]=statewise['Cured']*100/statewise['Confirmed']

# %%
statewise["Mortality Rate"]=statewise['Deaths']*100/statewise['Confirmed']

# %%
statewise=statewise.sort_values(by='Confirmed',ascending=False)

# %%
statewise.style.background_gradient(cmap='cubehelix')
# Out:
# <style type="text/css">
# #T_4f147_row0_col0, #T_4f147_row0_col1, #T_4f147_row0_col2, #T_4f147_row16_col4, #T_4f147_row36_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_4f147_row0_col3, #T_4f147_row4_col3, #T_4f147_row15_col3 {
#   background-color: #e9f8f2;
#   color: #000000;
# }
# #T_4f147_row0_col4 {
#   background-color: #d487b2;
#   color: #f1f1f1;
# }
# #T_4f147_row1_col0, #T_4f147_row31_col4 {
#   background-color: #637a2f;
#   color: #f1f1f1;
# }
# #T_4f147_row1_col1 {
#   background-color: #2d7038;
#   color: #f1f1f1;
# }
# #T_4f147_row1_col2, #T_4f147_row5_col0, #T_4f147_row5_col4, #T_4f147_row6_col1 {
#   background-color: #185b48;
#   color: #f1f1f1;
# }
# #T_4f147_row1_col3 {
#   background-color: #c4bdf1;
#   color: #000000;
# }
# #T_4f147_row1_col4 {
#   background-color: #607a2f;
#   color: #f1f1f1;
# }
# #T_4f147_row2_col0, #T_4f147_row12_col4 {
#   background-color: #577a2f;
#   color: #f1f1f1;
# }
# #T_4f147_row2_col1 {
#   background-color: #417731;
#   color: #f1f1f1;
# }
# #T_4f147_row2_col2, #T_4f147_row17_col0 {
#   background-color: #180f25;
#   color: #f1f1f1;
# }
# #T_4f147_row2_col3 {
#   background-color: #cce9ef;
#   color: #000000;
# }
# #T_4f147_row2_col4, #T_4f147_row13_col0 {
#   background-color: #1b1c3a;
#   color: #f1f1f1;
# }
# #T_4f147_row3_col0 {
#   background-color: #206840;
#   color: #f1f1f1;
# }
# #T_4f147_row3_col1 {
#   background-color: #1a6046;
#   color: #f1f1f1;
# }
# #T_4f147_row3_col2 {
#   background-color: #15464e;
#   color: #f1f1f1;
# }
# #T_4f147_row3_col3 {
#   background-color: #cdeaef;
#   color: #000000;
# }
# #T_4f147_row3_col4, #T_4f147_row4_col4 {
#   background-color: #817a37;
#   color: #f1f1f1;
# }
# #T_4f147_row4_col0, #T_4f147_row4_col1 {
#   background-color: #1f6741;
#   color: #f1f1f1;
# }
# #T_4f147_row4_col2, #T_4f147_row7_col0, #T_4f147_row17_col4 {
#   background-color: #15444f;
#   color: #f1f1f1;
# }
# #T_4f147_row5_col1 {
#   background-color: #16554b;
#   color: #f1f1f1;
# }
# #T_4f147_row5_col2, #T_4f147_row14_col0 {
#   background-color: #1b1a36;
#   color: #f1f1f1;
# }
# #T_4f147_row5_col3, #T_4f147_row26_col3 {
#   background-color: #d0ecef;
#   color: #000000;
# }
# #T_4f147_row6_col0 {
#   background-color: #16574b;
#   color: #f1f1f1;
# }
# #T_4f147_row6_col2 {
#   background-color: #17584a;
#   color: #f1f1f1;
# }
# #T_4f147_row6_col3 {
#   background-color: #fdfefe;
#   color: #000000;
# }
# #T_4f147_row6_col4 {
#   background-color: #d48cbe;
#   color: #f1f1f1;
# }
# #T_4f147_row7_col1 {
#   background-color: #16404e;
#   color: #f1f1f1;
# }
# #T_4f147_row7_col2, #T_4f147_row9_col0, #T_4f147_row29_col4 {
#   background-color: #192c47;
#   color: #f1f1f1;
# }
# #T_4f147_row7_col3 {
#   background-color: #dbf3ef;
#   color: #000000;
# }
# #T_4f147_row7_col4 {
#   background-color: #937a40;
#   color: #f1f1f1;
# }
# #T_4f147_row8_col0 {
#   background-color: #182f49;
#   color: #f1f1f1;
# }
# #T_4f147_row8_col1 {
#   background-color: #192d48;
#   color: #f1f1f1;
# }
# #T_4f147_row8_col2, #T_4f147_row10_col0 {
#   background-color: #1a2441;
#   color: #f1f1f1;
# }
# #T_4f147_row8_col3, #T_4f147_row19_col3, #T_4f147_row29_col3 {
#   background-color: #e0f5f0;
#   color: #000000;
# }
# #T_4f147_row8_col4 {
#   background-color: #b97964;
#   color: #f1f1f1;
# }
# #T_4f147_row9_col1, #T_4f147_row16_col2 {
#   background-color: #1a2543;
#   color: #f1f1f1;
# }
# #T_4f147_row9_col2, #T_4f147_row11_col2, #T_4f147_row12_col2 {
#   background-color: #181027;
#   color: #f1f1f1;
# }
# #T_4f147_row9_col3 {
#   background-color: #c5dff2;
#   color: #000000;
# }
# #T_4f147_row9_col4 {
#   background-color: #2b6f39;
#   color: #f1f1f1;
# }
# #T_4f147_row10_col1, #T_4f147_row11_col0 {
#   background-color: #1a213e;
#   color: #f1f1f1;
# }
# #T_4f147_row10_col2 {
#   background-color: #1a1835;
#   color: #f1f1f1;
# }
# #T_4f147_row10_col3 {
#   background-color: #d4efef;
#   color: #000000;
# }
# #T_4f147_row10_col4 {
#   background-color: #a1794a;
#   color: #f1f1f1;
# }
# #T_4f147_row11_col1, #T_4f147_row12_col0, #T_4f147_row35_col4 {
#   background-color: #1b1f3d;
#   color: #f1f1f1;
# }
# #T_4f147_row11_col3 {
#   background-color: #dcf3ef;
#   color: #000000;
# }
# #T_4f147_row11_col4 {
#   background-color: #54792f;
#   color: #f1f1f1;
# }
# #T_4f147_row12_col1 {
#   background-color: #1b1e3b;
#   color: #f1f1f1;
# }
# #T_4f147_row12_col3 {
#   background-color: #def4ef;
#   color: #000000;
# }
# #T_4f147_row13_col1, #T_4f147_row37_col4 {
#   background-color: #1b1b38;
#   color: #f1f1f1;
# }
# #T_4f147_row13_col2 {
#   background-color: #110815;
#   color: #f1f1f1;
# }
# #T_4f147_row13_col3, #T_4f147_row31_col3 {
#   background-color: #e3f6f0;
#   color: #000000;
# }
# #T_4f147_row13_col4 {
#   background-color: #16534c;
#   color: #f1f1f1;
# }
# #T_4f147_row14_col1 {
#   background-color: #1a1733;
#   color: #f1f1f1;
# }
# #T_4f147_row14_col2, #T_4f147_row17_col2, #T_4f147_row18_col2, #T_4f147_row22_col0, #T_4f147_row22_col2 {
#   background-color: #0b040c;
#   color: #f1f1f1;
# }
# #T_4f147_row14_col3 {
#   background-color: #cfebef;
#   color: #000000;
# }
# #T_4f147_row14_col4 {
#   background-color: #192845;
#   color: #f1f1f1;
# }
# #T_4f147_row15_col0, #T_4f147_row15_col1 {
#   background-color: #1a142f;
#   color: #f1f1f1;
# }
# #T_4f147_row15_col2 {
#   background-color: #0e050f;
#   color: #f1f1f1;
# }
# #T_4f147_row15_col4 {
#   background-color: #154b4e;
#   color: #f1f1f1;
# }
# #T_4f147_row16_col0 {
#   background-color: #19132d;
#   color: #f1f1f1;
# }
# #T_4f147_row16_col1 {
#   background-color: #191129;
#   color: #f1f1f1;
# }
# #T_4f147_row16_col3 {
#   background-color: #cbe8f0;
#   color: #000000;
# }
# #T_4f147_row17_col1 {
#   background-color: #160d21;
#   color: #f1f1f1;
# }
# #T_4f147_row17_col3 {
#   background-color: #c6e1f1;
#   color: #000000;
# }
# #T_4f147_row18_col0 {
#   background-color: #150b1d;
#   color: #f1f1f1;
# }
# #T_4f147_row18_col1, #T_4f147_row19_col0, #T_4f147_row20_col2 {
#   background-color: #140a1b;
#   color: #f1f1f1;
# }
# #T_4f147_row18_col3 {
#   background-color: #d1edef;
#   color: #000000;
# }
# #T_4f147_row18_col4 {
#   background-color: #1b6145;
#   color: #f1f1f1;
# }
# #T_4f147_row19_col1, #T_4f147_row19_col2 {
#   background-color: #130919;
#   color: #f1f1f1;
# }
# #T_4f147_row19_col4 {
#   background-color: #cf7e8f;
#   color: #f1f1f1;
# }
# #T_4f147_row20_col0 {
#   background-color: #120817;
#   color: #f1f1f1;
# }
# #T_4f147_row20_col1, #T_4f147_row21_col0 {
#   background-color: #100713;
#   color: #f1f1f1;
# }
# #T_4f147_row20_col3 {
#   background-color: #c5b8ef;
#   color: #000000;
# }
# #T_4f147_row20_col4 {
#   background-color: #cca6e4;
#   color: #000000;
# }
# #T_4f147_row21_col1, #T_4f147_row21_col2 {
#   background-color: #0f0611;
#   color: #f1f1f1;
# }
# #T_4f147_row21_col3 {
#   background-color: #c2d4f3;
#   color: #000000;
# }
# #T_4f147_row21_col4 {
#   background-color: #bc7967;
#   color: #f1f1f1;
# }
# #T_4f147_row22_col1, #T_4f147_row23_col0, #T_4f147_row23_col2 {
#   background-color: #0a030a;
#   color: #f1f1f1;
# }
# #T_4f147_row22_col3 {
#   background-color: #c1d1f3;
#   color: #000000;
# }
# #T_4f147_row22_col4 {
#   background-color: #d2809c;
#   color: #f1f1f1;
# }
# #T_4f147_row23_col1 {
#   background-color: #080308;
#   color: #f1f1f1;
# }
# #T_4f147_row23_col3 {
#   background-color: #c6e0f1;
#   color: #000000;
# }
# #T_4f147_row23_col4 {
#   background-color: #d48dc1;
#   color: #f1f1f1;
# }
# #T_4f147_row24_col0, #T_4f147_row33_col4 {
#   background-color: #070206;
#   color: #f1f1f1;
# }
# #T_4f147_row24_col1, #T_4f147_row24_col2 {
#   background-color: #050205;
#   color: #f1f1f1;
# }
# #T_4f147_row24_col3 {
#   background-color: #c2d6f3;
#   color: #000000;
# }
# #T_4f147_row24_col4, #T_4f147_row36_col4 {
#   background-color: #c87b7c;
#   color: #f1f1f1;
# }
# #T_4f147_row25_col0, #T_4f147_row25_col1, #T_4f147_row26_col0 {
#   background-color: #030103;
#   color: #f1f1f1;
# }
# #T_4f147_row25_col2, #T_4f147_row26_col1, #T_4f147_row26_col2, #T_4f147_row27_col0, #T_4f147_row27_col1, #T_4f147_row27_col2, #T_4f147_row28_col0, #T_4f147_row28_col2, #T_4f147_row29_col0, #T_4f147_row29_col1 {
#   background-color: #020102;
#   color: #f1f1f1;
# }
# #T_4f147_row25_col3 {
#   background-color: #d6f0ef;
#   color: #000000;
# }
# #T_4f147_row25_col4 {
#   background-color: #8d7a3d;
#   color: #f1f1f1;
# }
# #T_4f147_row26_col4 {
#   background-color: #6f7b31;
#   color: #f1f1f1;
# }
# #T_4f147_row27_col3 {
#   background-color: #c8e4f0;
#   color: #000000;
# }
# #T_4f147_row27_col4 {
#   background-color: #d383a6;
#   color: #f1f1f1;
# }
# #T_4f147_row28_col1, #T_4f147_row29_col2, #T_4f147_row30_col0,

# %%
#Top 10 Active case state
top_10_active_cases=covid_df.groupby(by='State/UnionTerritory').max()[['Active_cases','Date']].sort_values(by=['Active_cases'],ascending=False).reset_index()
fig= plt.figure(figsize=(16,9));
plt.title("Top 10 states with most active cases in India",size=25)

ax=sns.barplot(data=top_10_active_cases.iloc[:10],y='Active_cases',x='State/UnionTerritory',linewidth=2,edgecolor='red')

plt.xlabel("States")
plt.ylabel("Total active cases")
plt.show()

# %%
#Top states with highest deaths
top_10_deaths=covid_df.groupby(by='State/UnionTerritory').max()[['Deaths','Date']].sort_values(by=['Deaths'],ascending=False).reset_index()
fig= plt.figure(figsize=(18,5));
plt.title("Top 10 states with most deaths in India",size=25)

ax=sns.barplot(data=top_10_deaths.iloc[:12],y='Deaths',x='State/UnionTerritory',linewidth=2,edgecolor='red')

plt.xlabel("States")
plt.ylabel("Total deaths")
plt.show()
